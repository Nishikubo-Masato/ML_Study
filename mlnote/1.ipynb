# %%
# !pip install japanize-matplotlib
# Out:
# Collecting japanize-matplotlib
#   Using cached japanize_matplotlib-1.1.3-py3-none-any.whl
# Requirement already satisfied: matplotlib in c:\users\81907\anaconda3\lib\site-packages (from japanize-matplotlib) (3.5.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\81907\anaconda3\lib\site-packages (from matplotlib->japanize-matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\81907\anaconda3\lib\site-packages (from matplotlib->japanize-matplotlib) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\81907\anaconda3\lib\site-packages (from matplotlib->japanize-matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\81907\anaconda3\lib\site-packages (from matplotlib->japanize-matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\81907\anaconda3\lib\site-packages (from matplotlib->japanize-matplotlib) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\81907\anaconda3\lib\site-packages (from matplotlib->japanize-matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\81907\anaconda3\lib\site-packages (from matplotlib->japanize-matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\81907\anaconda3\lib\site-packages (from matplotlib->japanize-matplotlib) (9.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\81907\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->japanize-matplotlib) (1.16.0)
# Installing collected packages: japanize-matplotlib
# Successfully installed japanize-matplotlib-1.1.3

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches
import matplotlib.colors
import matplotlib.animation
from IPython.display import HTML
import japanize_matplotlib

# %%
X = np.array([
     9.1, 11.2, 12.3, 18.9, 22.2, 26. , 30.9, 31.2, 28.8, 23. , 18.3,
    11.1,  8.3,  9.1, 12.5, 18.5, 23.6, 24.8, 30.1, 33.1, 29.8, 23. ,
    16.3, 11.2,  9.6, 10.3, 16.4, 19.2, 24.1, 26.5, 31.4, 33.2, 28.8,
    23. , 17.4, 12.1, 10.6,  9.8, 14.5, 19.6, 24.7, 26.9, 30.5, 31.2,
    26.9, 23. , 17.4, 11. , 10.4, 10.4, 15.5, 19.3, 26.4, 26.4, 30.1,
    30.5, 26.4, 22.7, 17.8, 13.4, 10.6, 12.2, 14.9, 20.3, 25.2, 26.3,
    29.7, 31.6, 27.7, 22.6, 15.5, 13.8, 10.8, 12.1, 13.4, 19.9, 25.1,
    26.4, 31.8, 30.4, 26.8, 20.1, 16.6, 11.1,  9.4, 10.1, 16.9, 22.1,
    24.6, 26.6, 32.7, 32.5, 26.6, 23. , 17.7, 12.1, 10.3, 11.6, 15.4,
    19. , 25.3, 25.8, 27.5, 32.8, 29.4, 23.3, 17.7, 12.6, 11.1, 13.3,
    16. , 18.2, 24. , 27.5, 27.7, 34.1, 28.1, 21.4, 18.6, 12.3])

Y = np.array([
    463.,  360.,  380.,  584.,  763.,  886., 1168., 1325.,  847.,
    542.,  441.,  499.,  363.,  327.,  414.,  545.,  726.,  847.,
   1122., 1355.,  916.,  571.,  377.,  465.,  377.,  362.,  518.,
    683.,  838., 1012., 1267., 1464., 1000.,  629.,  448.,  466.,
    404.,  343.,  493.,  575.,  921., 1019., 1149., 1303.,  805.,
    739.,  587.,  561.,  486.,  470.,  564.,  609.,  899.,  946.,
   1295., 1325.,  760.,  667.,  564.,  633.,  478.,  450.,  567.,
    611.,  947.,  962., 1309., 1307.,  930.,  668.,  496.,  650.,
    506.,  423.,  531.,  672.,  871.,  986., 1368., 1319.,  924.,
    716.,  651.,  708.,  609.,  535.,  717.,  890., 1054., 1077.,
   1425., 1378.,  900.,  725.,  554.,  542.,  561.,  459.,  604.,
    745., 1105.,  973., 1263., 1533., 1044.,  821.,  621.,  601.,
    549.,  572.,  711.,  819., 1141., 1350., 1285., 1643., 1133.,
    784.,  682.,  587.])

icecream_data = (X,Y)
fig,ax = plt.subplots(dpi=100)
ax.scatter(x=X,y=Y,marker='.')
ax.set_xlabel("最高気温とアイスクリームの支出額")
ax.set_ylabel("支出額（円）")
ax.set_xlim(0,35)
ax.set_ylim(-250,2000)
ax.grid()
fig.show()
# Out:
# C:\Users\81907\AppData\Local\Temp\ipykernel_22036\2015091832.py:38: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
X = np.array([0, 35])
fig, ax = plt.subplots(dpi=100)
ax.scatter(icecream_data[0], icecream_data[1], marker='.')
ax.plot(X, 15 * X + 500, ls='--', color='tab:red')
ax.plot(X, 25 * X + 250, ls='-.', color='tab:red')
ax.plot(X, 40 * X + 0, ls='dotted', color='tab:red')
ax.set_title('最高気温とアイスクリーム・シャーベットの支出額')
ax.set_xlabel('最高気温の月平均（℃）')
ax.set_ylabel('支出額（円）')
ax.set_xlim(0, 35)
ax.set_ylim(-250, 2000)
ax.grid()
fig.show()
# Out:
# C:\Users\81907\AppData\Local\Temp\ipykernel_22036\2332865935.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
colormap = ['tab:red', 'tab:blue', 'tab:green', 'tab:orange']
offset_y = [0.5, 0.5, -0.5, -0.5]
xmin, xmax = 0, 10
ymin, ymax = 0, 10

def init_graph(dpi=100, grid=True):
    fig, ax = plt.subplots(dpi=dpi, figsize=(6, 6))
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)
    ax.set_aspect('equal')
    if grid:
        ax.grid()
    return fig, ax

def plot_data(ax,D,offset_y=None,marker="o"):
    A = []
    for i, row in enumerate(D):
        A.append(ax.scatter(D[i,0],D[i,1],marker=marker,color=colormap[i]))
        if offset_y is not None:
            A.append(ax.text(D[i,0], D[i,1] + offset_y[i], f'$(x_{i+1}, y_{i+1})$', ha='center'))
    return A

D = np.array([[1, 3], [3, 6], [6, 5], [8, 7]])
fig, ax = init_graph()
plot_data(ax,D,offset_y)
plt.show()
